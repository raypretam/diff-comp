# %%
# Total number of compounds to predict in test set
test_file_path = "/home/pretam-pg/DepNeCTI/DepNeCTI-XLMR/Trankit_Data/With Context/Finegrain/Finegrain_ood_san"

# Count compound end markers (each compound ends with Comp2_End, Comp3_End, etc.)
with open(test_file_path, 'r', encoding='utf-8') as f:
    total_compounds = sum(1 for line in f if '_End' in line)

# Count total sentences (DUMMY nodes)
with open(test_file_path, 'r', encoding='utf-8') as f:
    total_sentences = sum(1 for line in f if 'DUMMY' in line)

print(f"Total number of compounds to predict in test set: {total_compounds}")
print(f"Total number of sentences in test set: {total_sentences}")
print(f"Average compounds per sentence: {total_compounds/total_sentences:.2f}")
print(f"Test file: {test_file_path}")
# Out:
# Total number of compounds to predict in test set: 1803
# Total number of sentences in test set: 1139
# Average compounds per sentence: 1.58
# Test file: /home/pretam-pg/DepNeCTI/DepNeCTI-XLMR/Trankit_Data/With Context/Finegrain/Finegrain_ood_san
